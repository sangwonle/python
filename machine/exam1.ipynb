# %%
stname = "유니코"; stage=20; stavg=95.869
print(stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다")
print(stname, "학생은 나이가 ", stage, "이고 평균은 ", stavg, "입니다", sep="")
print("%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg))
print("{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg))
print(f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다")
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
v1 = stname+"학생은 나이가 "+str(stage)+"이고 평균은 "+str(stavg)+"입니다"
v2 = "%s학생은 나이가 %d이고 평균은 %.2f입니다" % (stname, stage, stavg)
v3 = "{}학생은 나이가 {}이고 평균은 {:.2f}입니다".format(stname, stage, stavg)
v4 = f"{stname}학생은 나이가 {stage}이고 평균은 {stavg:.2f}입니다"
print(v1)
print(v2)
print(v3)
print(v4)
# Out:
# 유니코학생은 나이가 20이고 평균은 95.869입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다
# 유니코학생은 나이가 20이고 평균은 95.87입니다

# %%
import sys
print(sys.version)
# Out:
# 3.8.12 (default, Oct 12 2021, 06:23:56)
# [Clang 10.0.0 ]

# %%
import os
print(os.getcwd())
# Out:
# /Users/isang-won/python_basic/machine

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   pydatavenv    /Users/isang-won/Library/Jupyter/kernels/pydatavenv
#   python3       /Users/isang-won/opt/anaconda3/share/jupyter/kernels/python3

# %%
# !dir
# Out:
# zsh:1: command not found: dir

# %%
import urllib.request
res = urllib.request.urlopen("http://www.naver.com/")
print(type(res))
print(res.status)
print(res.version)
print(res.msg)
res_header = res.getheaders()
print("[ header 정보 ]----------")
for s in res_header :
    print(s)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# 11
# OK
# [ header 정보 ]----------
# ('Server', 'NWS')
# ('Content-Type', 'text/html; charset=UTF-8')
# ('Cache-Control', 'no-cache, no-store, must-revalidate')
# ('Pragma', 'no-cache')
# ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"')
# ('X-Frame-Options', 'DENY')
# ('X-XSS-Protection', '1; mode=block')
# ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains')
# ('Referrer-Policy', 'unsafe-url')
# ('Vary', 'Accept-Encoding')
# ('Date', 'Tue, 11 Jan 2022 06:23:28 GMT')
# ('Transfer-Encoding', 'chunked')
# ('Connection', 'close')
# ('Connection', 'Transfer-Encoding')
# ('Set-Cookie', 'PM_CK_loc=40c6ebf84493aca3d2f2f8d06ca47ca7e802fdd421a228b86299f9cb7c38c0d8; Expires=Wed, 12 Jan 2022 06:23:28 GMT; Path=/; HttpOnly')

# %%
import urllib.request
res = urllib.request.urlopen("http://unico2013.dothome.co.kr/crawling/tagstyle.html")
print(res)
print("[ header 정보 ]----------")
res_header = res.getheaders()
for s in res_header :
    print(s)
print("[ body 내용 ]-----------")
#print(res.read())
print(res.read().decode('utf-8')) # 반드시 디코드를 해줘야 한글이 안깨진다.
# Out:
# <http.client.HTTPResponse object at 0x7fb878aea9d0>
# [ header 정보 ]----------
# ('Date', 'Tue, 11 Jan 2022 06:26:59 GMT')
# ('Server', 'Apache/2.2.15 (CentOS)')
# ('Content-Length', '461')
# ('Connection', 'close')
# ('Content-Type', 'text/html')
# [ body 내용 ]-----------
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>Insert title here</title>
# </head>
# <body>
# <h1>블럭스타일 태그</h1>
# <div style="background-color:yellow">테스트입니다1</div>
# <div>테스트입니다2</div>
# <div>테스트입니다3</div>
# <hr>
# <h1>인라인스타일 태그</h1>
# <span style="background-color:yellow">테스트입니다1</span>
# <span>테스트입니다2</span>
# <span>테스트입니다3</span>
# </body>
# </html>

# %%
import urllib.request
print("===========================================================")
url = 'https://www.python.org/'
f = urllib.request.urlopen(url)
print(type(f))
print(type(f.info()))
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
url = 'https://www.naver.com/'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)
text = f.read(500).decode(encoding)
print(text)
print("===========================================================")

url = 'http://www.yes24.com/Main/default.aspx'
f = urllib.request.urlopen(url)
encoding = f.info().get_content_charset()
print(url, ' 페이지의 인코딩 정보 :', encoding)

text = f.read(500).decode(encoding)
print(text)
print("===========================================================")
# Out:
# ===========================================================
# <class 'http.client.HTTPResponse'>
# <class 'http.client.HTTPMessage'>
# https://www.python.org/  페이지의 인코딩 정보 : utf-8
# <!doctype html>
# <!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->
# <!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->
# <!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jqu
# ===========================================================
# https://www.naver.com/  페이지의 인코딩 정보 : utf-8
#
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <m
# ===========================================================
# http://www.yes24.com/Main/default.aspx  페이지의 인코딩 정보 : ks_c_5601-1987
#
# 	<!DOCTYPE html>
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=euc-kr" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>Y
# ===========================================================

# %%
from urllib.parse import urlparse
from urllib.parse import urlencode
print("[ URL 문자열 정보 추출 1 ]")
url1 = urlparse('https://movie.daum.net/moviedb/main?movieId=93252')
print("타입정보 : ",type(url1))
print("도메인정보 : ",url1.netloc) 
print("패스정보 : ",url1.path)
print("쿼리정보 : ",url1.query) 
print("스킴정보 : ",url1.scheme)
print("포트정보 : ",url1.port)
print("프래그먼트정보 : ",url1.fragment)
print("URL 문자열정보 : ",url1.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url1)
print("\n[ URL 문자열 정보 추출 2 ]")
url2 = urlparse('https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object')
print("도메인정보 : ",url2.netloc) 
print("패스정보 : ", url2.path)  
print("쿼리정보 : ",url2.query)
print("스킴정보 : ",url2.scheme)
print("포트정보 : ",url2.port)
print("프래그먼트정보 : ",url2.fragment)
print("URL 문자열정보 : ",url2.geturl())
print("urllib.parse.ParseResult 객체정보 : ",url2)

print("\n[ Query문자열 또는 요청 파라미터 인코딩 ]")
params1 = urlencode({'number': 12524, 'type': 'issue', 'action': 'show'})
print(params1)
params2 = urlencode({'addr': '서울시 강남구 역삼동'})
print(params2)
# Out:
# [ URL 문자열 정보 추출 1 ]
# 타입정보 :  <class 'urllib.parse.ParseResult'>
# 도메인정보 :  movie.daum.net
# 패스정보 :  /moviedb/main
# 쿼리정보 :  movieId=93252
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :
# URL 문자열정보 :  https://movie.daum.net/moviedb/main?movieId=93252
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='movie.daum.net', path='/moviedb/main', params='', query='movieId=93252', fragment='')
#
# [ URL 문자열 정보 추출 2 ]
# 도메인정보 :  docs.python.org
# 패스정보 :  /3/library/urllib.parse.html
# 쿼리정보 :
# 스킴정보 :  https
# 포트정보 :  None
# 프래그먼트정보 :  urlparse-result-object
# URL 문자열정보 :  https://docs.python.org/3/library/urllib.parse.html#urlparse-result-object
# urllib.parse.ParseResult 객체정보 :  ParseResult(scheme='https', netloc='docs.python.org', path='/3/library/urllib.parse.html', params='', query='', fragment='urlparse-result-object')
#
# [ Query문자열 또는 요청 파라미터 인코딩 ]
# number=12524&type=issue&action=show
# addr=%EC%84%9C%EC%9A%B8%EC%8B%9C+%EA%B0%95%EB%82%A8%EA%B5%AC+%EC%97%AD%EC%82%BC%EB%8F%99

# %%
import urllib.request
import urllib.parse
params = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % params)
url = "http://unico2013.dothome.co.kr/crawling/get.php?%s" % params
with urllib.request.urlopen(url) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
print("URL 인코딩 규칙이 적용된 문자열 : %s" % data)
postdata = data.encode('ascii')
print("변환된 바이트 문자열 : %s" % postdata)
url = "http://unico2013.dothome.co.kr/crawling/post.php"
with urllib.request.urlopen(url, postdata) as f:
    print(f.read().decode('utf-8'))
# Out:
# URL 인코딩 규칙이 적용된 문자열 : name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10
# 변환된 바이트 문자열 : b'name=%EC%9C%A0%EB%8B%88%EC%BD%94&age=10'
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import urllib.request
import urllib.parse
data = urllib.parse.urlencode({'name': '유니코', 'age': 10})
postdata = data.encode('ascii')
req = urllib.request.Request(url='http://unico2013.dothome.co.kr/crawling/post.php',
            data=postdata)
print(req)
with urllib.request.urlopen(req) as f:
    print(f.read().decode('utf-8'))
# Out:
# <urllib.request.Request object at 0x7fb878b27310>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 유니코이고 나이는 10이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.request('get', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('head', 'http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
print('----------------------------------------------------------')
r = requests.request('post', 'http://unico2013.dothome.co.kr/crawling/post.php', data= {'name':'백도', 'age' : 12})
r.encoding = 'utf-8'
print(type(r))
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')
# Out:
# <class 'requests.models.Response'>
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <title>테스트</title>
# </head>
# <body>
# <h1>웹 크롤링을 테스트 합니다.</h1>
# </body>
# </html>
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# 응답된 콘텐츠가 없어요
# ----------------------------------------------------------
# <class 'requests.models.Response'>
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>POST : 이름은 백도이고 나이는 12이네요!!</h1>   </body>
# </html>

# %%
import requests

r = requests.get('http://unico2013.dothome.co.kr/crawling/exam.html')
r.encoding = 'utf-8'
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

r = requests.head('http://unico2013.dothome.co.kr/crawling/exam.html')
print(type(r))
print(r.headers)
if r.text :
    print(r.text)
else :
    print('응답된 콘텐츠가 없어요')

# %%
import requests

dicdata = {'이름': '홍길동', '나이': 20}
urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr, params=dicdata)
print(r.url)
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
dicdata = {'key1': 'value1', 'key2': ['value2', 'value3']}
r = requests.request('GET', urlstr, params=dicdata)
print(r.url)
print('------------------------------------')
tupledata = [('key1', 'value1'), ('key1', 'value2')]
r = requests.get(urlstr, params=tupledata)
print(r.url)
# Out:
# http://unico2013.dothome.co.kr/crawling/get.php?%EC%9D%B4%EB%A6%84=%ED%99%8D%EA%B8%B8%EB%8F%99&%EB%82%98%EC%9D%B4=20
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key2=value2&key2=value3
# ------------------------------------
# http://unico2013.dothome.co.kr/crawling/get.php?key1=value1&key1=value2

# %%
import requests

urlstr = 'http://unico2013.dothome.co.kr/crawling/get.php'
r = requests.get(urlstr)
print(r.text)
print('------------------------------------')
r.encoding = 'utf-8'
print(r.text)
print('------------------------------------')
print(r.content)
print('------------------------------------')
print(r.content.decode('utf-8'))
# Out:
# ï»¿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : ì´ë¦ê³¼ ëì´ë¥¼ ì ë¬í´ ì£¼ì¸ì!!</h1>   </body>
# </html>
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>
# ------------------------------------
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<html>\r\n  <head>\r\n    <meta charset="utf-8">\r\n    <title>POST TEST</title>\r\n  </head>\r\n  <body>\r\n   <h1>GET : \xec\x9d\xb4\xeb\xa6\x84\xea\xb3\xbc \xeb\x82\x98\xec\x9d\xb4\xeb\xa5\xbc \xec\xa0\x84\xeb\x8b\xac\xed\x95\xb4 \xec\xa3\xbc\xec\x84\xb8\xec\x9a\x94!!</h1>   </body>\r\n</html>'
# ------------------------------------
# ﻿<!DOCTYPE html>
# <html>
#   <head>
#     <meta charset="utf-8">
#     <title>POST TEST</title>
#   </head>
#   <body>
#    <h1>GET : 이름과 나이를 전달해 주세요!!</h1>   </body>
# </html>

# %%
import requests
from PIL import Image
from io import BytesIO

r = requests.get('http://unico2013.dothome.co.kr/image/flower.jpg')
i = Image.open(BytesIO(r.content))
print(type(i))
i.save("output/test.jpg")
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
    <head>
        <meta charset="utf-8">
        <title>Test BeautifulSoup</title>
    </head>
    <body>
        <h1>테스트</h1>
    </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Test BeautifulSoup
#   </title>
#  </head>
#  <body>
#   <p align="center">
#    P태그의 컨텐트
#   </p>
#   <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300"/>
#  </body>
# </html>

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.title), ':', bs.title)
print(type(bs.title.name), ':', bs.title.name)
print(type(bs.title.string), ':', bs.title.string)
print('-------------------------')
print(type(bs.p['align']), ':', bs.p['align'])
print(type(bs.img['src']), ':', bs.img['src'])
print(type(bs.img.attrs), ':', bs.img.attrs)
# Out:
# <class 'bs4.element.Tag'> : <title>Test BeautifulSoup</title>
# <class 'str'> : title
# <class 'bs4.element.NavigableString'> : Test BeautifulSoup
# -------------------------
# <class 'str'> : center
# <class 'str'> : http://unico2013.dothome.co.kr/image/flower.jpg
# <class 'dict'> : {'src': 'http://unico2013.dothome.co.kr/image/flower.jpg', 'width': '300'}

# %%
html_doc = """
<!DOCTYPE html>
<html>
     <head>
          <meta charset='utf-8'>
          <title>Test BeautifulSoup</title>
     </head>
     <body>
          <p align="center">P태그의 컨텐트</p>
          <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="300">
          <ul>
               <li>테스트1<strong>강조</strong></li>
               <li>테스트2</li>
               <li>테스트3</li>
          </ul>
     </body>
</html> """
from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print("[ string 속성 ]")
print(type(bs.p.string), ':', bs.p.string)
print(type(bs.ul.string), ':', bs.ul.string)
print(type(bs.ul.li.string), ':', bs.ul.li.string)
print(type(bs.ul.li.strong.string), ':', bs.ul.li.strong.string)
print("[ text 속성 ]")
print(type(bs.p.text), ':', bs.p.text)
print(type(bs.ul.text), ':', bs.ul.text)
print(type(bs.ul.li.text), ':', bs.ul.li.text)
print(type(bs.ul.li.strong.text), ':', bs.ul.li.strong.text)
print("[ contents 속성 ]")
print(type(bs.p.contents), ':', bs.p.contents)
print(type(bs.ul.contents), ':', bs.ul.contents)
print(type(bs.ul.li.contents), ':', bs.ul.li.contents)
print(type(bs.ul.li.strong.contents), ':', bs.ul.li.strong.contents)
print("[ find_all()의 text=True 매개변수 ]")
print(bs.find_all("li", text=True))  # 콘텐츠가 텍스트로만 구성된

# %%
html_doc="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right">  text contents 2 </p>
     <p align="left">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
     <div>
       <p>text contents 4</p> 
     </div>
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html_doc, 'html.parser')
print(type(bs.find('p')))
print(type(bs.find_all('p')))
print("---------------------------------")
print(bs.find('title'))
print(bs.find('p'))
print(bs.find('img'))
print("---------------------------------")
ptags = bs.find_all('p')
print(ptags)
print("----------------")
for tag in ptags :
    print(tag)

# %%
html="""
<!DOCTYPE html>
<html>
  <head>
     <meta charset='utf-8'>
     <title>Test BeautifulSoup</title>
  </head>
  <body>
     <p align="center"> text contents </p>
     <p align="right" class="myp">  text contents 2 </p>
     <p align="left" a="b">   text contents 3 </p>
     <img src="http://unico2013.dothome.co.kr/image/flower.jpg" width="500">
  </body>
</html> """

from bs4 import BeautifulSoup
bs = BeautifulSoup(html, 'html.parser')
print(bs.find('p', align="center"))
print(bs.find('p', class_="myp"))
print(bs.find('p', align="left"))
print("-------------------------------------")
print(bs.find('p', attrs={"align":"center"}))
print(bs.find('p', attrs={"align":"right", "class":"myp"}))
print(bs.find('p', attrs={"align":"left"}))

pdom = bs.find('p', align="left")
print("["+pdom.text+"]")
print("["+pdom.get_text(strip=True)+"]")
print("["+pdom.string.strip()+"]")

# %%
import requests
from bs4 import BeautifulSoup

req = requests.get('http://unico2013.dothome.co.kr/crawling/exercise_css.html')
html = req.content
print(type(html))
html = html.decode('utf-8')
#print(html)
print("==============================")
bs = BeautifulSoup(html, 'html.parser')
title = bs.select('h1')
title1 = bs.select('#f_subtitle')
title2 = bs.select('.subtitle')
title3 = bs.select('aside > h2')
img = bs.select('[src]')
print(title)
print(type(title))
print(type(title[0]))
print("<h1>태그의 갯수 : %d " %len(title))
print("f_subtitle이라는 id 속성을 갖는 태그 갯수 : %d " %len(title1))
print("subtitle이라는 class 속성을 갖는 태그 갯수 : %d " %len(title2))
print("aside 태그의 <h2> 자식 태그 갯수 : %d " %len(title3))
print("src 속성을 갖는 태그 갯수 : %d " %len(img))

for content in title:
    print(content.string)
print("------------------------------")
for content in title1:
    print(content.text)
print("------------------------------")
for content in title2:
    print(content.text)
print("------------------------------")
for content in title3:
    print(content.text)
print("------------------------------")
for content in img:
   print(content["src"])
# Out:
# <class 'bytes'>
# ==============================
# [<h1>CSS 선택자 학습</h1>]
# <class 'bs4.element.ResultSet'>
# <class 'bs4.element.Tag'>
# <h1>태그의 갯수 : 1
# f_subtitle이라는 id 속성을 갖는 태그 갯수 : 1
# subtitle이라는 class 속성을 갖는 태그 갯수 : 2
# aside 태그의 <h2> 자식 태그 갯수 : 1
# src 속성을 갖는 태그 갯수 : 1
# CSS 선택자 학습
# ------------------------------
# 교육과정 소개
# ------------------------------
# 웹 클라이언트 기술
# 학습 순서(수집)
# ------------------------------
# 학습 순서(수집)
# ------------------------------
# https://www.python.org/static/img/python-logo.png

# %%
import requests
from bs4 import BeautifulSoup
import re
req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page=1')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
titles = soup.select('.movie')
points = soup.select('td.title > div > em')
reviews = soup.select('td.title')
movie_title = []
movie_point = []
movie_review = [] 

for dom in titles:
    movie_title.append(dom.text)
for dom in points:
    movie_point.append(dom.text)
for dom in reviews:
    content = dom.contents[6] 
    #content=re.sub("신고", '', content)
    content=re.sub("[\n\t]", '', content)  # 자연어처리(텍스트공백 전처리) 공백 없애기
    movie_review.append(content)
commentLength = len(movie_title)   
for i in range(commentLength):
    print("영화 제목 : " + movie_title[i])
    print("평점 : " + movie_point[i])
    print("리뷰글 : " + movie_review[i])
    print("-----------------------------------------")
# Out:
# 영화 제목 : 특송
# 평점 : 10
# 리뷰글 : 볼영화 없었는데 코로나도 뚫고가서 보기를 잘한듯요!!배우들 연기도 좋고 아역과 박소담의 연기도 돋보임!!
# -----------------------------------------
# 영화 제목 : 경관의 피
# 평점 : 6
# 리뷰글 : 조진웅의 단독 드리블,거침없는 것이 결코 좋은 것은 아니다란걸 알면 50대가 되어 있을겁니다
# -----------------------------------------
# 영화 제목 : 경관의 피
# 평점 : 10
# 리뷰글 : 스토리도 탄탄하고 배우님들의 연기다 너무 좋아요.
# -----------------------------------------
# 영화 제목 : 아수라
# 평점 : 10
# 리뷰글 : 감독과 작가의 혜안에 Respect!
# -----------------------------------------
# 영화 제목 : 스파이더맨: 노 웨이 홈
# 평점 : 10
# 리뷰글 : 나는야 스덕 ㅈㄴ게마싯다 이번거빨리 4 나와줘
# -----------------------------------------
# 영화 제목 : 하우스 오브 구찌
# 평점 : 10
# 리뷰글 : 레이디가가의 재능이 빛을 발한 영화배드신은 그야말로 올해 최고의 배드신 ㅋㅋㅋ
# -----------------------------------------
# 영화 제목 : 씽2게더
# 평점 : 10
# 리뷰글 : 캐릭터들 성격이 뚜렷하고 매력이 있어서 좋았음.Ost나 영상미도 좋고
# -----------------------------------------
# 영화 제목 : 웨스트 사이드 스토리
# 평점 : 10
# 리뷰글 : wrns님아 ㅋㅋ 개봉 첫 조조시간이 8시20분인가 그거인데 8시20분 영화여도 156분가량의 러닝타임이라 지금은 상영중인데 개봉하자마 봤다고? ㅋㅋㅋ
# -----------------------------------------
# 영화 제목 : 아수라
# 평점 : 10
# 리뷰글 : 소름돋네 진짜 찢 애들이 테러했네ㄷㄷㄷㄷ
# -----------------------------------------
# 영화 제목 : 아수라
# 평점 : 10
# 리뷰글 : 아수라는진짜실화였다
# -----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import re
for n in range(1,31):
    req = requests.get('http://movie.naver.com/movie/point/af/list.nhn?page='+str(n))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    titles = soup.select('.movie' )
    points = soup.select('td.title > div > em')
    reviews = soup.select('td.title')
    movie_title = []
    movie_point = []
    movie_review = [] 
    for dom in titles:
        movie_title.append(dom.text)
    for dom in points:
        movie_point.append(dom.text)
    for dom in reviews:
        content = dom.contents[6]
        content=re.sub("[\n\t]", '', content)
        movie_review.append(content)

    commentLength = len(movie_title)   
    for i in range(commentLength):
        print(movie_point[i] + ","+movie_title[i]+","+movie_review[i])
    print("-----------------------------------------------------")
# Out:
# 10,아멜리에,
# 10,웨스트 사이드 스토리,로미와 줄리엣 같았던 토니와 마리아의 러브 스토리:)
# 10,스파이더맨: 노 웨이 홈,최고의 영화였습니다.
# 10,웨스트 사이드 스토리,
# 8,유체이탈자,액션은 최고   내용은 가볍지만 적당함. 개연성이 조금 떨어지지만 무시해도 될만함..
# 8,램,남의 자식을 허락도 없이 데려와 키우다가 응보를 받게 되는 스토리?
# 10,특송,올해 최고의 영화입니다
# 10,웨스트 사이드 스토리,믿고 보는 감독과 기억에 남는 음악.. 좋아요ㅎㅎ
# 10,컬러풀 웨딩즈,제 인생 최고의 영화 중 하나였습니다. 강추합니다. 감상하면 대부분은 절대 후회 안 하실 거라고 확신합니다.
# 10,웨스트 사이드 스토리,스토리는 로맨틱하고, 퍼포먼스는 역동적이고, 연출은 완벽하고, 메시지는 뜨겁다!
# -----------------------------------------------------
# 4,웨스트 사이드 스토리,현대에 이해를 요구하기엔 너무 올드하고 진부한 스토리. 루즈한 진행. 도저히 공감하고 몰입할 수가 없는 주인공들.... 스필버그 작이라고 올려치기엔 오래된 영화라는 느낌밖엔 받을 수 없었다. 배우들의 연기와 음악은 좋았다.
# 8,웨스트 사이드 스토리,생각보다는 아쉽다..
# 10,특송,자동차 추격신 좋고 배우들 연기도 굿
# 10,장난스런 키스,정말 이건 대만 최고의 하이틴이다..장난스런 키스 후회 안한다 다 보세여 ???-???
# 8,스파이더맨: 노 웨이 홈,아쉬움 많지만 코로나때 영화중 이정도면 대박.
# 10,스파이더맨: 노 웨이 홈,스파이더맨 최고의 감동이네요
# 10,특송,108분이 18분처럼 감쪽같이 순삭과 동시에 박소담의 걸크러쉬 액션까지 시원하게 폭발한 영화!
# 10,클리포드 더 빅 레드 독,애들용 영화인줄 알았는데 다 큰 내가 눈물 흘림 ㅠㅠㅠ
# 8,미드 90,나름 재밌다. 90년대 감성 물씬
# 7,펠로니,꽤잘나가던 남자가 음주운전으로 한순간에 나락간영화 영화초반 음주운전하는 순간부터 나락갈건 이미 예고되었다 다들 운주운전하지마세요 인생 한방에 나락감
# -----------------------------------------------------
# 10,클리포드 더 빅 레드 독,클리포드 귀욤 따뜻한 영화에요
# 10,클리포드 더 빅 레드 독,왕크니까 왕귀엽다!
# 9,경관의 피,나쁜 놈들과 싸울때 때로는 나빠질 필요도 있다는 메세지가 좋은 것 같아요문재앙을 비롯한 쓰레기들, 이 세상에 재앙을 일으키는 자들 처단하러 같이 가요!
# 10,특송,박소담..진짜 이제 믿고 보는 원픽이다..최고야
# 10,하우스 오브 구찌,믿고보는 레이디 가가노래와 연기 두가지를 가진 천재적 재능!
# 10,웨스트 사이드 스토리,믿고 보는 거장 스티븐 스필버그 감독의 데뷔 이래 최초로 어메이징 하면서 놀라운 뮤지컬 영화
# 10,웨스트 사이드 스토리,투나잇 음악 쵝오..배우들 케미도 너무 좋고 음악이 계속 귀에 멤도는듯. 간만에 재미있게 본 뮤지컬영화임
# 10,특송,최근에 본영화중1등!
# 10,클리포드 더 빅 레드 독,사랑만큼 커지는 강아지와 그 특별함 속에서 나타나는 감동적인 서사!재관람하고 싶어하는 아이!
# 10,특송,큰기대안하고 봤는데 기대이상입니다. 꼭보세요
# -----------------------------------------------------
# 8,스파이더맨: 노 웨이 홈,초중반에 잠깐 졸기도 하고.. 기대를 너무 많이해서 그런지 그냥 볼만했음전작 배우들 다 섭외한건 정말 대단하다고 생각함
# 9,스탠리의 도시락,스탠리의 밝고 명랑함이 순수함이 아니란것이 너무슬프다ㅠ 세상 모든 아이들만이라도 평등했으면.. 여선생님, 점원형 같은사람 한명만있어도 스탠리는 훌륭한 어른이될거다.
# 10,씽2게더,흥미로운 스타일 볼만합니다!
# 9,킹스맨: 퍼스트 에이전트,기대가 현저했으나 의외로 재밌었다.
# 2,특송,여기가 진짜 알바천국!
# 7,경관의 피,대사는 안들리고 소리는 시끄럽고 보다 중간에 잤음
# 10,특송,꿀잼이네옄ㅋㅋㅋ 카체이싱 대박 ㅋㅋㅋ
# 10,특송,ㄹㅇ팝콘무비ㅋㅋㅋ 새해 첫 영화로 잘봤습니다~ 재밌어요!
# 10,아수라,아수라는진짜실화였다
# 8,스파이더맨: 노 웨이 홈,모든 스파이더맨 시리즈의 등장인물들과 팬들을 위한 헌정영화라고 생각됐음... 그래서 쌩으로 처음보는사람은 재미있게 보기힘들듯 합니다ㅜ이전 스파이더맨 영화 시리즈들이랑 스파이더맨 등장하는 마블 시리즈들 대충이라도 흝어보고가면 좋을듯합니다,,,
# 10,특송,박소담배우 액션도 잘하는구나... 영화 시작부터 카체이싱 너무 멋있었음bb
# 10,웨스트 사이드 스토리,미접종자라 못보지만 재밌습니다  물론 이 영화를 못보는 제 상황이재밌네요
# -----------------------------------------------------
# 5,클레어의 카메라,칸에서, 노느니 하나 찍지 뭐, 하고 찍은, 홍상수 소품
# 10,특송,VIP 시사회 , 유료 관람회로 총 2번 봤는데 역시 2번봐도 질리지 않네요 카체이싱 장면도 좋았고 OST가 좋았습니다 모가디슈 이후 가장 좋은 한국영화 였어요
# 10,씽2게더,If you want it~ take it~
# 8,해피 뉴 이어,배우들 라인업이 너무 재밌다
# 10,특송,송새벽 악역 연기 미쳤어;; 역대급 연기
# 10,특송,박소담 송새벽등의 연기는 말하지 않아도 일품이고 화끈하게 평쳐지는 레이싱 추격전을 스릴이 넘칩니다 . 음악또한 신나고  긴장감있어 영화를 더 몰입해서 볼 수 있었습니다
# 10,웨스트 사이드 스토리,처음부터 끝까지 눈과 귀를 황홀하게 하는 영화였음..진짜 큰 스크린으로 볼 가치가 충분했다ㅠㅠ
# 10,특송,박소담 송새벽등의 연기는 말하지 않아도 일품이고 화끈하게 평쳐지는 레이싱 추격전을 스릴이 넘칩니다 . 음악또한 신나고  긴장감있어 영화를 더 몰입해서 볼 수 있었습니다
# 10,특송,송새벽 악역 연기 미쳤어;; 역대급 연기
# 10,경관의 피,나이스한 영화입니다~
# -----------------------------------------------------
# 10,웨스트 사이드 스토리,레이첼 지글러가 보여준 2022년판 완벽한 마리아...완전 캐릭터 그 자체였음!! 오늘부터 입덕 1일
# 10,웨스트 사이드 스토리,마지막에 마리아의 눈빛은 진짜 천상의 크리스탈을 보는 것 같이 아름다웠다. 스필버그 감독의 옛 뮤지컬의 재해석은 원작을 대체하려는 시도 아니고 또 다른 느낌의 웨스트 사이드 스토리를 만든 것 같다.
# 10,스파이더맨: 노 웨이 홈,
# 1,패트리어트,ㅋㅋ... 이게 영화라니... 어이없어 웃음만 나온다...ㅋㅋ
# 10,경관의 피,
# 10,특송,저번주에 이미 시사회로 관람했는데 기대이상으로 재밌었구요. 2022년 새해 첫 시작을 알리는 범죄액션 오락영화
# 10,특송,ost는 황정민배우님 친형이 하신거네요
# 10,포화 속으로,내 인생전쟁영화('퓨리'랑 TOP1,2) (덩케르크 미드웨이 헥소고지 장사리 1917 태극기휘날리며 라이언일병 이미테이션게임 작전병발키리 진주만 인천상륙작전 보다 나음)
# 1,페인킬러 엑스,허... 참... 총체적 난국이네
# 10,특송,Ost가 대박이네요! 심장을 뛰게하는 ost에요
# -----------------------------------------------------
# 9,씽2게더,정말이지 이 영화는 눈과 귀가 즐거운데다 감동까지 느끼게 하는 에니메이션의 정수라고 본다!
# 10,캐리비안의 해적 - 세상의 끝에서,캐리비안의 해적 영화중에 제일 재밌음 오예!!!!
# 10,특송,오락무비로 즐기기에 딱!ㅋㅋㅋ 박소담 연기 너무 잘해
# 10,퓨리,인생 전쟁영화 '퓨리'('포화속으로' 랑 동급)(덩케르크 미드웨이 헥소고지 장사리 1917 태극기휘날리며 라이언일병 이미테이션게임 작전병발키리 진주만 인천상륙작전 보다 나음)
# 5,폭풍 탈주,비디오 대여해서 보던기억이 나네 시간때우기용임
# 1,블랙 위도우,영화가 무지 심심하고, 폴페이그가 감독을 해야지 딴 사람이 함? 폴페이그님 블랙위도우 2편은 폴 페이그님이 각본해주세요
# 10,특송,박소담의 액션과 카체이싱 짜릿해씀 팝콘무비로 굿굿
# 10,특송,시사회에서 시간순삭으로 봤다오랜만에 통쾌한 영화ost 멋짐
# 8,고스트버스터즈 라이즈,새로운 시리즈를 위한 구세대와 신세대를 아우르는훌륭한 접점 피비 매력 터짐
# 10,웨스트 사이드 스토리,역시 스티븐스필버그 감독은 실망시키지않아!
# -----------------------------------------------------
# 2,스파이더맨 3,블랙슈트입기전에도 빌런처럼 행동했음 샌드맨 때문에 그나마 잼있다는것입니다
# 8,주먹왕 랄프,그 자리에서 최선을 다하는것, 악당도 주인공도!
# 7,벌새,디테일한 내면이 마치 옆집을 굽어살펴보는듯한
# 10,씽2게더,1편을 안 보고 요약만 보고 갔는데, 영화 보는 데 문제 없었습니다. 영화 너무 감동적이고 좋았어요.
# 8,스파이더맨: 노 웨이 홈,피터는 정말로 자기가 "그런 사람 아닌지"를 영영 의심할 것이다. 풍족할 때 친절하고 다정한 것은 누구나 가능하고, 그 애는 이미 한번 칼을 들었으므로. 모든 걸 잃고도 슈트를 뒤집어써서, 다만 더 나아지려고 노력할 뿐이다(Trying to do better.) 피터의 유년이 끝난다. Kid시절과의 작별이다. 그렇게 어른이 된다. 안녕, Spider-Man.
# 5,돈,영화에 희망소비자가격이 필요하다.
# 1,스파이더맨: 노 웨이 홈,역대 최악의 스파이더맨!정의에 대한 정의가 완벽히 잘못되어있다고 본다.생명의 소중함은 인정하는데 우선 죄를 지었으면 책임을 져야한다.이미 그 악당들은 너무나 많은 인명피해와 그리고 물질적인 피해를 많이 줘서 더이상 평범한 생활은 불가능 한 사람들이다.그런 그 사람들을 교화시키겠다고 건물이 박살나고 자신의 가족이 죽고경찰차도 박살나고 등등 말도 안되는 죄를 지었는데도곱게 돌려보낸 것도 웃기고그들 중에 원래대로 돌아가기 원하지 않는 사람도 많았는데 억지로 그렇게 만드는 것도 웃기고ㅋㅋㅋ특히 전기쓰는 놈은! 걔는 악을 선택했다. 그런놈 살리자고 그렇게 희생을 한다는게 납득할 수 없고그런 말도 안되는 정의에 대한 생각이 이 사회에도 퍼지게 될까봐 두렵다.정말 최악의 영화이게 원작 스토리라면 정말 실망했다.이럴거면 그냥 어벤져스 엔드게임에서 다 끝내는게 나았다고 본다.보고나서도 기분 그지 같은 느낌 너무 싫다.
# 10,스파이더맨: 노 웨이 홈,마블 보고 3번 울었는데 인피니트워에서 피터 “암소리”하고 사라질때 엔드게임에서 토니 “암아이언맨”하고 핑거스냅할때 노웨이홈에서 피터가 MJ 구하고 “알유오케이”할때
# 10,씽2게더,역시 여기가 노래맛집
# 10,하우스 오브 구찌,구찌 매출 수요될 것으로 예상됩니다. 구찌는 역시 굿
# -----------------------------------------------------
# 10,스파이더맨: 노 웨이 홈,짱잼~~~굿
# 10,아수라,이건 영화가 아니라 다큐다
# 6,찬실이는 복도 많지,감동적인 찬실이의 극복기
# 9,무드 인디고,아름답고 화려한 소품, 색감, 영상미,  결코 가볍지 않은 메세지를 담고있는 영화. 인생이란 행복하고  잔혹하기도한 동화같음.
# 10,듄,2회차 관람하였는데요. 세계관을 잡고 보시는 것을 추천 드립니다. 호불호의 기준이 이것 때문인거 같아요. 진짜 잘 만든 영화입니다!
# 10,특송,박소담 액션 보러 갔다가 뜻밖의 송새벽 캐릭터에 반하고 오는 영화 진짜 송새벽의 재발견 은하x미영 서사도 풀어주쇼 ㅠㅠ
# 8,특송,러닝타임 동안 잠시 코로나를 잊고 시원하고 짜릿한 시간을 선물해준 영화
# 10,특송,액션이랑 ost 조화 미쳤다ㅋㅋ 박소담 액션도 기대 이상이었음
# 10,스파이더맨: 노 웨이 홈,인생 처음 평점 다는데 이 영화는 그냥 말도 안됨..ㅠㅠ
# 10,특송,카체이싱과 액션이 아주 뛰어났음ㅎㅎㅎ시사회로 보고 온 1인!
# -----------------------------------------------------
# 10,특송,박소담은 정말 최고!!
# 2,경관의 피,박희순 웅얼웅얼  머래니,
# 1,마더/안드로이드,시작부터 일단 흑인 억지로 꾸겨넣은거에서 느낌이 안좋았는데 보다가 화가나서 도중에 껐다. 이제는 억지 pc는 기본장착이고 내용에 개연성을 pc와 바꿔먹었는지 이해를 할수가없는 전개방식
# 8,그들만의 월드컵,스포츠는 아름답다.
# 7,아나콘다,한국아재들이 있었다면 아나콘다로 술을 담글 것이여~ㅋ. 존 보이트의 악당연기 쩐다.
# 1,프리랜서스,진짜... 이걸왜본건지 이게 영화인건지ㅋㅋ한시간반을 그냥 날려버렸네...무슨 내용인지 진짜 하나도 모르겠음 멀 연출하고싶은건지ㅋ
# 5,램,부족한 연출을 풍경과 시나리오로 극복하고자 했지만
# 10,낙원의 밤,느와르 좋아하는데 너무 명작이다 ㅠㅠ 왜 지금 알았지? 차승원 엄태구 양사장 여쥔공 어느 누구 하나빠지지 않는 연기력 최근 느와르 중에 1빠드림
# 8,스파이더맨: 노 웨이 홈,너무 재밌게 봤는데 결말이 너무 찌통.. 내 아기거미..
# 2,콜,중간부터 끝까지 짜증나면서 봄 영화가 너무 다크하고 사이다가 없음 끝까지 고구마 3천4백만개 먹은느낌
# -----------------------------------------------------
# 10,베놈 2: 렛 데어 비 카니지,생각없이 재밌게보기 좋았음
# 4,핫 블러드,너무 액션에만 치우친 느낌 스토리는 엉망
# 6,신기전,네이버 영화 평점은, 지 애비한테 가정 교육을 제대로 못 받은 한남들만 남기나보다. 뭔 평점에 맨날 여자 탓, 여자 조롱, 몸매 평가질, 연기 지적질만 해대냐...이 벌레같은 한남들은 강간범보다 소리 지르는 여자가 더 불편한가봐 ㅉㅉ이 벌레같은 한남들은 발연기하는 남자 배우 지적하는 꼴은 본적이 없어.남배우가 발연기하면 로봇이니 뭐니 하면서 긍정적으로 웃으면서 넘어가.근데 여배우가 연기 좀 서툴르면 정색을 하고 물어뜯어..진짜 나도 남자지만 이 나라 한남들은 벌레 소릴 처들어도 된다. 애비들이 어떻게 가정 교육을 시켰길래 강간범한텐 찍소리도 못 하면서, 여자가 소리 지르는 걸 불편해 하냐..진짜 니들 낳은 애미가 불쌍하다..작성자tuna****       튜나야 니가 여자라는데 내전재산하고 손모가지 건다 넌 모걸래? 이젠하다하다 영화 감상평에 미친 여초페미 등장하네 아 나라가 어케될라고 아주 말세네 말세야 나라꼴 잘돌아간다 널 낳은 애미가 더 불쌍 쯧쯧쯧
# 8,대부 3,감독딸은 외모가 너무 학구파적이라, 이런 역활엔 안맞는듯...예쁜 얼굴이긴한데.. 코가 너무 크고 여자로서의 매력이 없어요. 소피아 코폴라 때문에 몰입도 깨졌습니다. 본인도 느꼈는지, 연기보다는 감독 활동으로 나선듯..
# 10,배심원들,추리 드라마라 긴장감에서 오는  몰입도가 높고 스토리 자체가 좋다.주위에 꼭 추천해 주고 싶은 영화
# 10,이터널스,시간가는줄 모르고봤다!!역시 이터널스 ^~^
# 9,10일 안에 남자 친구에게 차이는 법,가끔은 이런 유치한 영화를 보는 것이 갑갑한 현실에 활력을 준다고 생각한다. 아름다운 주인공들을 보는 것만으로 기분이 한결 좋아짐.
# 1,마더/안드로이드,넷플릭스 top10 영화 상단에 뜨고 클레이 모레츠라서 봤는데 진짜 아쉽다는 수준을 넘어서 화가나네 뭔데 이게
# 6,저스트 프렌드,라이언레이놀즈 최고의 배우지만 너무 똑같은 모습이 질리네요 사만다가 왜 키스상을 받았는지 알겠고 남창희 닮은분도 인상깊네요  어릴때 트라우마 학대 따돌림 이런건 평생 가는구나 생각드네요
# -----------------------------------------------------
# 8,샹치와 텐 링즈의 전설,재미없다길래안볼려고했는데기대없이 봐서 그런가 지루하지않고 재밌음
# 9,스파이더맨: 노 웨이 홈,시존 스파이더맨 시리즈팬의 묵은 아쉬움을 해소해주는 영화하지만 액션에 아쉬움이 느껴졌다
# 7,경관의 피,최우식과 조진웅의 연기가 괜찮았습니다.
# 6,모가디슈,신파없이 감동적이라고 하는데 전혀 공감 못하겠음. 내가 보기엔 뻔하디 뻔한 신파 같은데. 인슐린 떡밥부터 느낌 오더니 역시는 역시였다. 갑분 북한이랑 으쌰으쌰 위아더 코리아...ㅋㅋㅋㅋ 조인성 캐릭터는 참 좋았음. 배우들 연기도 좋았고. 다만 뻔한 스토리에 억지 국뽕 억지 감동이 몰입을 깨버렸을 뿐.
# 10,양들의 침묵,스릴러 영화의 완성형.
# 10,해피 데스데이,진짜 진짜 재밌슴 여주도 이쁘고 긴장감도 살벌함!!
# 10,더 킹,검찰개혁 꼭 해야된다.노무현 대통령 당선되면 안된다자나
# 2,싱크홀,개노잼 진짜 할거 없으신분들 보세요
# -----------------------------------------------------
# 10,파이트 클럽,파이트클럽이 재미없다는 못배워처먹은 새끼들은 영화에 대해 논하지 마라
# 10,씽2게더,와우 마지막에 폴샤가 외계인 옷 입고 노래하는 장면에서 너무 아름답고 소름끼쳐서 눈물나올 뻔했네요 강추합니다 더빙으로 봤는데 자막으로 한 번 더 보고싶어요 ㅎㅎ
# 10,스파이더맨: 노 웨이 홈,작년에 봤는데 이제서야 리뷰를 쓰다니... 보러 갈 때 별 기대를 하지 않았는데 너무 재미있었음. 직접 보는게 스포보단 100배는 나을 것 같으니 스포는 하지 않겠음
# 1,오늘의 연애,평생 영화보고 평점 1점 주긴 처음 ㅜㅜ내 아까운 시간 ㅜㅜ
# 8,파이트 클럽,90년도에 있지도 않던 새끼들이 예전에 나온 영화를 지금 여기서 까고 자빠졌네
# 2,부러진 화살,석궁들고 찾아간건 맞는데 아따 무죄랑게요 ㅋㅋ
# 8,스파이더맨: 노 웨이 홈,3 파이더맨 볼수 있는것만드로 행보했습니다 헬로 피러~
# 10,돈 룩 업,존잼 웃음으로시작해서마지막에 감동으로 끝남
# 9,씽2게더,마지막 사자 노래가 약간짪아서 아쉬웠다
# 10,씽2게더,너무 재밌어요ㅠㅠ 특히 포르샤 뛰어내리면서 노래부르는 장면... 너무 소름돋고 너무 감동적이네요!! 꼭 보세요 강추
# -----------------------------------------------------
# 10,카오스 워킹,
# 10,파이트 클럽,최고의 영화!!!!,
# 5,파이트 클럽,그냥저냥 볼만함
# 1,파이트 클럽,습,..뭔개소리를 하는지 하나도모르겠음...
# 10,파이트 클럽,찐따새끼들아 평점테러 하지마라
# 10,파이트 클럽,최고의반전
# 1,마담 뺑덕,천박한 영화. 정우성이 얼마나 연기를 못하는지 증명하는 영화.
# 10,위플래쉬,명작 이건 무조건 봐야됨
# 1,파이트 클럽,개노잼
# 6,기적,배우들이 아깝다 아싑다
# -----------------------------------------------------
# 1,유전,그냥 홍머병 걸린 사람들이 재밌다고 생각할 영화. 자기가 똥 해석하면서 즐기는 사람이라면 강추. 마지막 결말은 인간이라면 느끼는 징그럽고 더럽고 역겨운거 모아놓고 와!! 무섭지!!! 이러는거 같음. 너무 재미없어서 그냥 기분 더러워짐
# 1,파이트 클럽,당시에는 좋은 영화였을지도 모르지만, 지금은 아니다. 내 인생 최악의 영화
# 6,007 노 타임 투 다이,이렇게 끝낸다고? 감독이 일본인인가.. 일본 색채가 강하네. 좀 !! 역대 007작품중에서 오염 많이된 작품. 젠장.. 카지노로얄에서 그 강단있던 모습이 참.. 가족이 생겨서 그런건가 싶지만.. 여튼 좀더 가족때문에 비굴할거면 더 비굴해야지. 여튼.. 아쉬움
# 7,경관의 피,우식이의 뿔테안경을 본 것 만으로 충분
# 10,월드워Z,정말 잘만든명작 좀비영화중 으뜸
# 10,100미터,가슴이 뭉클해지는 정말 감동적인 영화였습니다.
# 10,파이트 클럽,복선, 연출 좋은 블랙코미디 영화
# 8,악마가 너의 죽음을 알기 전에,이게 감독 마지막 작품이였군요 허탈하지만 잘 봤습니다
# 10,파이트 클럽,개인적으로 인생 최고의영화라고 생각합니다.클레멘타인과 같이 감동도 있고 반전의 반전을 거듭한 숨막히는 스토리 무엇보다도 배우들의 연기가 엄청났습니다. 99년에 나온 영화임에도 불구하고 요즘 나오는 영화들과 비교해도 손색없을정도로 엄청난 명작입니다. 꼭 보세요 꼭 꼭 꼭 꼭
# 1,해피 뉴 이어,제가 봤던 영화중 가장 재미없습니다 보지마세요
# -----------------------------------------------------
# 7,스파이더맨: 노 웨이 홈,
# 1,파이트 클럽,이딴 걸 본 게 내 인생 최대의 실수였다
# 1,파이트 클럽,정신병이 있으시면 치료를 받으시라구요
# 8,딥워터,더이상 안될꺼같으면 다리를 자르고 올라오던가 아오...언니는 그냥 고구마그자체
# 8,파이트 클럽,올드한 영화이나 연출은 그냥 볼만 했음 이제는 낡은 영화.
# 1,파이트 클럽,웃음밖에 나오지 않는 영화
# 10,파이트 클럽,나만 당할수는 없지..
# 2,파이트 클럽,이게 모...머나요오오옷
# 1,파이트 클럽,똥
# 1,파이트 클럽,지식이 없어서 말은 못하겠습니다.하지만 감상은 개 재미없었습니다
# -----------------------------------------------------
# 3,파이트 클럽,스토리도 없고.. 한시간반동안 정신나간 소리만하다가 반전때문에 기대했는데 결말은 개같이 멸망
# 1,파이트 클럽,이거 추천한 사람은 정신상태를 잘 살펴봐야함...어디 뭐 홍머병이나 아스퍼거 증후군 의심됨도대체... 이걸... 하...
# 1,파이트 클럽,정말 피트형의 연기는 존설이다 꼭 감상해보세효“야추 클럽”
# 1,파이트 클럽,2022년에 보기엔 미안하지만 '똥' 그 자체다.영화가 담은 이야기가 너무 낡았어요.ㅇㅇ
# 10,친구2,오랜만에 다시 봐도 재미있게 끝까지 다 보게 되는데 재미있고 좋게 잘 만들었다고 생각합니다.
# 10,파이트 클럽,나만 당할 수 없지 ㄹㅇㅋㅋ
# 1,파이트 클럽,난 잘모르겠다 볼사람은 토컨하면서 보셈
# 2,파이트 클럽,시대적인 흐름에 잘 탄 작품일 수는 있겠다만, 시대를 관통하는 작품은 아닌 듯 보인다. 감독이 무엇을 표현하려 했는지도 모르겠고, 결국 내용이 무엇인지 영화 끝나고서도 이해를 못하겠다.
# 1,파이트 클럽,칵퉤 감상포인트같은소리하네
# 10,스파이더맨: 노 웨이 홈,네이버 포인트 준다해서 10점줌
# -----------------------------------------------------
# 1,파이트 클럽,개재미없는 영화의 표본그자체 홍대병걸린 그들만 재밌다고하는 평점주작의 현실 그냥 2시간동안 누워자는게 인생에 훨씬 도움됨
# 10,파이트 클럽,왁타버스 멀티버스에선 파이트클럽이 거품이라고??
# 1,파이트 클럽,내 인생 최악의 영화 ㅇㅇ
# 5,파이트 클럽,좀 지루한부분도 있고 약간 흥미로운 부분도 있어서 재미도는 중간쯤이고 내용이랄까 감독의 의도랄까 이런부분은 그냥 그렇게 와닿지는 않음
# 1,파이트 클럽,하...,,, 시간 날렸어 ㄹㅇ
# 1,파이트 클럽,하... 뭘 만든 것입니까. 괜히 봤네...
# 7,팬텀 스레드,내가 맞출게의 극단적 예시.
# 1,파이트 클럽,내 인생 최악의 영화
# 8,혐오스런 마츠코의 일생,구부렸다 쫙 펴도 별에 닿지 못했지만, 별에 닿기는 커녕 아프게 바닥으로 곤두박질 쳤지만, 그녀가 남긴 사랑의 흔적은 별똥별처럼 남아 어둔 하늘을 비춰주었다.
# 2,파이트 클럽,그 당시에만 신선하고 지금은 그저 망작의 기준이 되어야할 작품 의식의 흐름을 가지고 만들어도 이정도 철학보다 많이 담겨있을 듯하다. 개연성이 있기는 하지만 제대로 이어지지 않으며 몇번을 다시 보고 "아 이건 명작이네"라고 느낄 정도면 재미 없는 영화다. 내용도 심오하지도 않고 철학적이지도 않고 브래드 피트랑 에드워드 노튼이 연기를 얼마나 잘 하는지만 알 수 있었다. 블랙 코미디? 그건 시대에 맞기 때문에 위대한 것이지 지금 봤을때 과거에 그 나라가 어떤 상황이였고 어떤 일이 있었으면 어떤 반응이었나를 공부해가면서까지도 볼 이유가 없는 영화다.
# -----------------------------------------------------
# 1,파이트 클럽,1점도 아까움 0점도 아까움 진짜 눈 버리고 뇌 버림;; 명작이라고 띄우지 마세요 이런게 명작이면 정작 못 뜬 영화들 중에서도 명작들 많음 그런게 ㄹㅇ 명작이지 이건 진짜 토악질 나옴 노래가 제일 좋음 그.나.마
# 1,파이트 클럽,후..
# 1,파이트 클럽,아빠!!! 일어나!!!
# 10,틱, 틱... 붐!,이 영화 한 편으로 이번 달 결제비는 전혀 아깝지 않았습니다.
# 1,파이트 클럽,진짜 진지하게 평점 높게준사람들 아무리 생각해도 이해안가면 개추 ㅋㅋㅋㅋ
# 1,파이트 클럽,이건 2022년에 볼 수 있는 수준의 영회가 아니다
# 1,파이트 클럽,무슨 이런 개 같은 영화가 다있음?
# 2,파이트 클럽,진짜 쥰나 빡치네. 이게 인생 명작?
# 1,파이트 클럽,
# 1,파이트 클럽,스토리가 없으며 뭘 말하고자 하는지 모르겠음
# -----------------------------------------------------
# 1,파이트 클럽,이건 아니야 제발...
# 10,위아 유어 프렌즈,확실한 하이를 잡아주고 강한여운을 남기는 영화
# 10,파이트 클럽,나만 보기 아까운 영화,,, 망작이라 하는 사람 조용히 하세요.. 나만 당하고 싶지 않음..
# 10,소스 코드,
# 10,결혼 이야기,그 누구도 결혼식에서는 예상할 수 없는 이별 그 이상의 잔혹함
# 2,파이트 클럽,진짜 무슨 생각으로 점수 높게 주는거지?하나의 정신병인가주인공이랑 똑같네속아서 봤네
# 7,킹스맨: 퍼스트 에이전트,1917이 되고싶었던 액션장르. 1편과 더불어 충격적인 씬이 있지만 마찬가지로 중요한 등장인물을 허무하게 소비하는 점은 여전히 같다. 하지만 그러지 않으면 충격적이지 않으니 딜레마랄까. 리얼리티를 살린 킹스맨일수도 있고, 픽션을 가미한 1917일수도 있다. 어떻게 보느냐에 따라 영화에 대한 평이 갈릴것.
# 1,파이트 클럽,우왁굳 방송보고 화나서 왔으면 개추 ㅋㅋ
# 1,파이트 클럽,네이버 평점 9.5점보고 낚여서 봤네. 다보고나니 13명이 만든 평점임 개같은거
# 10,고양이에게 밥을 주지 마세요,마음 따뜻하고 훈훈해지는 좋은 영화예요
# -----------------------------------------------------
# 2,파이트 클럽,한마디로 wow였다고 본다
# 1,파이트 클럽,미친 개똥망작이다 이건
# 1,파이트 클럽,불쾌하기만 한 중2병 홍머병 영화
# 1,파이트 클럽,야이 쓰레기들아 니들이 그러고도 사람이냐
# 1,파이트 클럽,하...내가 뭘 본거지
# 1,파이트 클럽,정말 개똥쓰레기 영화 뭘 말하려는지도 이상하고 확실한건 이 시대에 보면 개똥 쓰레기라는것
# 4,친구2,진부하다 진부해 다 때려 넣었네...
# 2,세자매,다들좋은영화라는데왜난 보는내내 불쾌하고 답답하고..괜히본영화네요연기를잘하면 좋은영환가요?
# 10,씽2게더,진짜 이거 안 본 사람들에게 말하고 싶다 이거 안 보면 2022년 즐겁게 시작 못한다....진짜 OST는 말할것도 없고 스토리도,영상미도 빠지는게 없다진짜 와...
# 10,돈 룩 업,뭔데 이렇게 재밌냐 뻔한 소재를 이렇게 센스있게 풀어가다니ㄷㄷ
# -----------------------------------------------------
# 2,파이트 클럽,왁굳형... 이건 똥이 맞네...
# 7,아무도 없다,장르에 신선한 내용을 가져온다던가 하는 건 아닌데,, 그래도 재미있게 잘 만든 영화이다. 로튼토마토 지수 보면 90퍼센트 먹고 그러던데 우리나라 평론가들은 왜..?
# 7,죽을 때까지,초반부는 약간 지루했지만 나머지 부분은 꽤 괜찮았다.
# 5,더 퍼지,소재도 좋고, 배경도 나쁘지 않고, 초반부도 괜찮았는데...전체적으로 실망스러웠다.
# 3,더 파이브,되게 잘 못 만든 일본 영화같음 연기는 박효주하고 정수영씨 말고는 볼거도 없음
# 3,파이트 클럽,솔직히 2022년에 와서 보기엔 너무 유치하고 수준 낮은 영화입니다.. 반전이라는 요소와 당시에 없던 액션 연출들 때문에 시대를 잘 타서 고평가 받은 듯 하네요. 수정 날짜확인
# 3,파이트 클럽,우왁굳 선정 3점짜리 영화
# 2,파이트 클럽,이거 클레멘타인임;;;; 평점 장난질 ㅅㅂ
# 4,모노노케 히메,전체적으로 잘 짜여진 영화같지만 대사 하나하나 살펴보면 한마디로 걸캅스 같아요…
# 10,웨스트 사이드 스토리,우리는 이 뮤지컬을 평생동안 두고두고 생각해야 한다
# -----------------------------------------------------
# 5,졸업반,영화는 현실적으로 있을만큼 짝사랑 하는 주인공 모두 현실성 있고 스토리도 좋다 아쉬운점은 아직 우리나라 애니는 너무 부족하다 일본 애니따라갈려면 한참 멀듯 한국애니에도 좀 투자좀했으면 좋겠다
# 1,파이트 클럽,뭐 연기 좋고 코미디적 요소가 많아 즐겁게 봤습니다만은... 보는 내내 어딘가 불편했던 영화. 자본주의가 그렇게 싫으면 원시인처럼 동물 사냥하면서 너네들끼리 공동체 이뤄서 사세요 ㅋㅋ 거기선 빈부격차가 안생길까? 혹여 전염병이라도 한번 돌면 그때서야 비로소 현재가 행복했다는걸 알게될듯.. 누릴거 다 누리는 시대에 살면서 불평불만만 많은 정신병 환자가 테러하면서 자위하는 영화 그이상이하도 아님.. 이영화에 공감하는 분들, 내마음 한켠에도 타일러가 있다는 분들은 정신좀 차리시고 건강한 오늘이 감사한줄 알길
# 10,드라이브 마이 카,미쳤어요 진한 연극적 감동을 영상으로 느끼다니마지막에 ~ 크게 쏟아내리는 진동과  여운 어쩔런지이 감독 미쳤다리
# 10,사도,두번째봐도 찡한영화...ㅜㅜ
# 10,온다,드럽게 무섭네. 인간의 심리 잘 표현
# 1,강릉,스토리가 없음… 120분 러닝타임 내내 서로 칼질하고 쑤시고 하는 장면밖에 없음…
# 10,더 플랫폼,신, 인간 , 구원에 대한 갈구 , 소원 , 선함 , 악함에 대한 단상.
# 8,엔칸토: 마법의 세계,상 받을 만하다 아주 좋다
# 10,경관의 피,진짜 믿고 보는 최우식 배우님의 연기! 배우분들 합이 다 좋으셔서 개인적으로 너무너무 재밌게 본 영화!
# 10,헌터 킬러,존잼이다. 설명이 필요없어
# -----------------------------------------------------

# %%
print(reviews[0].contents)

# %%
import requests
from bs4 import BeautifulSoup

urlstr = 'http://www.yes24.com/SearchCorner/Search?domain=BOOK&query=python'
r = requests.get(urlstr)
#r.encoding = "utf-8"
bs = BeautifulSoup(r.text, 'html.parser')
booklist = bs.select('a.gd_name')

title = []
link = []

for bookdom in booklist:
    title.append(bookdom.string)
    link.append(bookdom["href"])

print("-- 도서 제목 --")
print(title)
print("-- 도서 링크 URL --")
print(link)
with open('output/booklink.csv', "wt", encoding="utf-8") as f:
    f.write('booktitle,booklink\n')  
    for i in range(len(title)):
        f.write(title[i]+","+link[i]+'\n')
# Out:
# -- 도서 제목 --
# ['Do it! 점프 투 파이썬', '혼자 공부하는 파이썬', '혼자 공부하는 머신러닝+딥러닝', '이것이 취업을 위한 코딩 테스트다 with 파이썬 ', 'Do it! 파이썬 생활 프로그래밍', 'Do it! 점프 투 파이썬 + Do it! 파이썬 생활 프로그래밍', '밑바닥부터 시작하는 딥러닝 ', 'Do it! 첫 파이썬', 'Do it! 점프 투 파이썬 + Do it! 첫 파이썬 ', '파이썬 알고리즘 인터뷰', '핸즈온 머신러닝', '파이썬 머신러닝 완벽 가이드', 'Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편', 'Do it! 점프 투 파이썬 + Do it! 자료구조와 함께 배우는 알고리즘 입문 : 파이썬 편 + Do it! 파이썬 생활 프로그래밍', '파이썬을 이용한 비트코인 자동매매', '파이썬 증권 데이터 분석 ', '모두의 인공지능 기초 수학', '혼자 공부하는 첫 프로그래밍 with 파이썬 ', '밑바닥부터 시작하는 딥러닝 2', '모두의 데이터 분석 with 파이썬', '모두의 알고리즘 with 파이썬', '프로그래머를 위한 수학 : 파이썬으로 하는 3D 그래픽스, 시뮬레이션, 머신러닝', '웹 크롤링 & 데이터 분석 with 파이썬', '한권으로 파이썬과 드론 날로 먹기 인공지능 편']
# -- 도서 링크 URL --
# ['/Product/Goods/74419916', '/Product/Goods/74269975', '/Product/Goods/96024871', '/Product/Goods/91433923', '/Product/Goods/91437485', '/Product/Goods/91446225', '/Product/Goods/34970929', '/Product/Goods/89904189', '/Product/Goods/91446188', '/Product/Goods/91084402', '/Product/Goods/89959711', '/Product/Goods/87044746', '/Product/Goods/91219874', '/Product/Goods/91446242', '/Product/Goods/98135876', '/Product/Goods/90578506', '/Product/Goods/91358533', '/Product/Goods/90617738', '/Product/Goods/72173703', '/Product/Goods/72227684', '/Product/Goods/40443936', '/Product/Goods/106045879', '/Product/Goods/106175772', '/Product/Goods/106157392']

# %%
from bs4 import BeautifulSoup
import urllib.request as req
import io

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"
savename =